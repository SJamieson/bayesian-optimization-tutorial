# %% [markdown]
# # Bayesian Optimization Tutorial
# **By Stewart Jamieson & Björn Lütjens**
#
# *Using this Tutorial:*
#
# Throughout this tutorial, you will see code blocks. Oftentimes, they will contain a block of code like this:
# ```python
# ## Play here!
# ...
# ## Now stop playing
# ```
# These are meant to highlight regions of the code where different parameters are defined, so that you can experiment with how these parameters change the algorithm. Bear in mind that these hyperparameters may have far-reaching effects on the whole tutorial! For example, changing the `offset` value in the first code block will affect every other generated plot in the tutorial.
#
# Feel free to change code outside these regions - but be warned that this could likewise have far-reaching effects, possibly breaking code later in the tutorial.
#
# ### Introduction
# For this tutorial, we will attempt to find the global minima of the function $f(x)=(2e^{-x} |x + 4sin(x)| + \delta)$ in the domain $x \in [0,10]$ (we will generally stick with $\delta=-8$).
# Though we have the explicit formula, it is a complicated enough function that you probably can't deduce the location of this minima by inspection.
# What are some of the other strategies we could try?
#  - Gradient descent (requires gradient)
#  - Newton's method (requires gradient)
#  - Random sampling in the interval $[0,10]$
#
# With access to the gradient (or a numerical approximation of it), we have a couple options. These methods tend to be quite fast at finding optima when evaluting the function takes just microseconds or milliseconds, since they are similarly computationally easy and thus allow thousands of iterations per second. But what if evaluating our function was not so easy?
#
# For example, what if instead of the above equation, $f(x)$ represented the validation loss of a large neural network after training it on an image dataset, as a function of the hyperparameters of the network (e.g. the learning rate $\alpha$)? This is shown in the following plot:
#
# ![cnn-tuning.png](cnn-tuning.png)
#
# In this real example, evaluating the neural network loss $f(x)$ for different hyperparameters $x$ took days! This
# could likewise be the case if $f(x)$ represented the amount of algae in one part of a lake - evaluating our function then requires deploying
# a team of robots or scientists to go to the location, collect the data, and report back the results.
#
# In these cases, simple methods such as those described above are highly inefficient: gradient descent usually relies on a small step size,
# which means that it could take thousands or millions of function evaluations; Newton's method and other higher-order optimization methods require access to the gradient, Hessian, etc, which often cannot even be approximated easily. Must we resort to random sampling in these cases?
#
# Bayesian optimization is a tool for using Bayesian statistical analysis to select highly "informative" points to evaluate, when solving some kind of optimization problem. It is relatively computationally expensive to compute these informative points, but in cases where the function being optimized is far more expensive then this is a worthy tradeoff.
#
# The two components of Bayesian optimization are:
# 1. A model for approximating the target function $f(x)$
# 2. An "acqusition function" $a(x)$ that tells us how informative it would be for us to sample at location $x$
#
# An obvious way to model the target function $f(x)$ is to run a regression on our sample $(x,y)$ pairs. As Bayesian data scientists, we will employ a Gaussian process for this regression.

# %%
## Make sure to run this cell first to import dependencies!

## Uncomment the following line if IPython (or Binder) complains about dependencies
# !pip install scipy sklearn numpy matplotlib ipython

from IPython.display import display
import scipy.stats as stats
from plotting import FunctionPlot
import matplotlib.pyplot as plt
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Modelling $f(x)$ with a Gaussian Process
#
# First, let's see what our function actually looks like:

# %%
## Play here!
offset = -8
def f(x):
    """The function to optimize."""
    return 2 * np.exp(-x) + np.abs(x + np.sin(x) * 4) + offset
## Now stop playing.

## Plot the function
fig : plt.Figure = plt.figure()
ax : plt.Axes = fig.gca()
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
func_plot = FunctionPlot(ax, 'Bayesian Optimization', (0, 10), (0 + offset, 16 + offset))
xs = func_plot.x
func_plot.add_function(r'$f(x)$', f, style='r.', markersize=2, locked=True)

plt.show()

# %% [markdown]
# We can see clearly that the global minima is located around $x=4.5$, but there are other minima at the boundaries of our domain. To model the function with a Gaussian Process, we first need to choose its hyperparameters.
#
# As in previous classes, we will pick the Radial-Basis Function kernel (also known as the Squared-Exponential or Gaussian kernel) for our covariance, and a zero mean. For the kernel, we will pick the parameters $l=0.5, \sigma_n = 0.05$.
#
# Note: You may recall that we previous had another kernel parameter $\sigma_f$, representing the variance of the function. Instead, we will estimate this parameter as we collect training data. This is done because the Gaussian Process implementation we are using expects the variance of our samples to always be $1$, so we treat $\sigma_f$ as a normalization quantity that we initialize to $1$.

# %%
## Play here!
length_scale = 0.5
sigma_noise = 1E-1
zero_mean = True
initial_sigma_f = 1
kernel = RBF(length_scale=length_scale)
# kernel = Matern(length_scale=length_scale, nu=0.5)
## Now stop playing.

def init_gp():
    gp = GaussianProcessRegressor(kernel=kernel, 
                                  alpha=sigma_noise**2,
                                  normalize_y=not zero_mean)
    return gp, initial_sigma_f


def scaled_predict(gp, points, ub):
    mean, std = gp.predict(points, return_std=True)
    return mean * ub, std * ub

func_plot.reset()
gp, sigma_f = init_gp()
func_plot.add_function('GP Prediction', 
                       lambda x: scaled_predict(gp, x, sigma_f), 
                       style='b-', f_sigma_style='b')
display(fig)

# %% [markdown]
# Now that we have our Gaussian Process model, we just need a way to collect observations. We will assume that our observations of the true function have additive Gaussian noise, possibly with a different sigma value than our GP covariance hyperparameter.

# %%
## Play here!
# Note that the model will likely do best if true_noise is set to the same value as sigma_noise
true_noise = 1E-1
## Now stop playing.

def y(x):
    if isinstance(x, np.ndarray):
        return f(x) + np.random.normal(0, true_noise, x.shape)
    else:
        return f(x) + np.random.normal(0, true_noise)

def train_gp(gp, train_x, train_y):
    train_x = np.array(train_x).reshape(-1,1)
    train_y = np.array(train_y).reshape(-1)
    func_plot.mark_point(train_x, train_y, 'y*', markersize=10)
    sigma_f = np.sqrt(np.sum(np.power(train_y, 2)) / train_y.shape[0])
    gp.fit(train_x, train_y / sigma_f)
    return sigma_f

def plot_gp(func_plot, gp, sigma_f):
    func_plot.add_function(None,
                           lambda x: scaled_predict(gp, x, sigma_f), 
                           style='b-', f_sigma_style='b')

# %% [markdown]
# To test if our model is working, let's take 4 evenly spaced samples from across the domain.

# %%
## Play here!
fixed_xs = [0, 10.*1/3, 10.*2/3, 10.]
## Now stop playing

test_x = np.array(fixed_xs, dtype=np.float64).reshape(-1, 1)
test_y = y(test_x)

func_plot.reset()
sigma_f = train_gp(gp, test_x, test_y)
plot_gp(func_plot, gp, sigma_f)
display(fig)

# %% [markdown]
# ## The Acquisition Function
#
# ### Probability of Improvement $a_\text{PI}$
#
# A simple and intuitive acquisition function is the probability of improvement. This is the probability that a sample at a given location will result in a value lower than our current best value by at least some value $\xi \ge 0$:
#
# \begin{equation}
# a_\text{PI}(x) = P(f(x) \le f(x_\text{best}) - \xi)
# \end{equation}
#
# Under our GP model with training data $\{x_n,y_n\}$ and hyperparameters $\theta$ this has a closed form solution:
#
# \begin{equation}
# a_\text{PI}(x) = \Phi\left(\frac{f(x_\text{best}) - \mu(x; \{x_n,y_n\}, \theta) - \xi}{\sigma(x; \{x_n,y_n\}, \theta)}\right)
# \end{equation}
#
# Let's see what it looks like initially:

# %%
func_plot.reset()
gp, sigma_f = init_gp()

def PI(gp, x, sigma_f, f_best, xi=0):
    mean, std = scaled_predict(gp, x, sigma_f)
    gamma = np.divide(f_best - mean.reshape(-1) - xi, std.reshape(-1))
    return stats.norm.cdf(gamma)

def plot_PI(func_plot, gp, sigma_f, f_best, xi=0, scale=5):
    func_plot.add_function(f'$a_{{PI}}$ ($\\xi={xi}$)',
                           lambda x: (PI(gp, x, sigma_f, f_best, xi) * scale), 
                           style='y--', f_sigma_style='b', 
                           linewidth=2.5)

plot_gp(func_plot, gp, sigma_f)
plot_PI(func_plot, gp, sigma_f, 0)
display(fig)

# %% [markdown]
# As we might expect, since there is no training data yet then our acquisition function $a_\text{PI}$ has the same value everywhere. So, we pick the first point randomly to be $x=1$:

# %%
## Play here!
train_x  = [1]
## Now stop playing.

train_y = [y(train_x[0])]
func_plot.reset()
sigma_f = train_gp(gp, train_x, train_y)
f_best = np.max(train_y)

plot_gp(func_plot, gp, sigma_f)
plot_PI(func_plot, gp, sigma_f, f_best)
display(fig)

# %% [markdown]
# Now we can see that our acqusition function has changed with the GP. However, the new maximum of the acqusition function is at $x=1$, which is where we just sampled! This exposes a flaw in our choice of $\xi = 0$; this value of $\xi$ indicates that we are happy with points that are equal to our previous best value, but in fact we are only interested in places where the function is lower.
#
# A visual example of what $\alpha_\text{PI}$ represents may give us more intuition on why this happens. In the following plots, the area of the magenta shaded region represents the probability of improvement. It is computed as the following area under the normal PDF:
#
# \begin{equation}
# \mathcal{N}(y \le (f_\text{best} - \xi); \mu(x), \sigma(x))
# \end{equation}

# %%
def show_PI_distribution(gp, sigma_f, f_best, x, xi=0):
    func_plot.reset()
    plot_PI(func_plot, gp, sigma_f, f_best, xi=xi)
    plot_gp(func_plot, gp, sigma_f)
    func_plot.hline(f_best - xi, 'k--', alpha=0.5, label=r'$f_{best} - \xi$')
    x = np.array(x).reshape(-1, 1)
    ys, sigma = scaled_predict(gp, x, sigma_f)
    func_plot.add_normal_pdf(x[0,0], ys[0], sigma, 'k--', scale=2,
                             highlight_below=f_best-xi, highlight_color='m')
    display(fig)

## Play here!
show_PI_distribution(gp, sigma_f, f_best, 1)
show_PI_distribution(gp, sigma_f, f_best, 1.5)
show_PI_distribution(gp, sigma_f, f_best, 5)

# %% [markdown]
# This visual helps us to see why a larger $\xi$ will help. In the first case, the variance is very small so most of the probability density is very close to the sample location. In the second case, the probability density more spread out. In the third case, the density is even more spread out, but since the mean is much higher than hardly any of the mass is below $f_\text{best}$. Let's try again with $\xi = 0.5$:

# %%
## Play here!
show_PI_distribution(gp, sigma_f, f_best, 1, xi=0.5)
show_PI_distribution(gp, sigma_f, f_best, 1.3, xi=0.5)
show_PI_distribution(gp, sigma_f, f_best, 5, xi=0.5)

# %% [markdown]
# This seems much more useful. Now, instead of suggesting the same point, the acquisition function suggests points slightly further away, which have a balance between a low mean and a higher variance.
#
# Let's run a few more iterations to see how it performs. To do so, we'll define a function to suggest the next point, which is the maximum of the acquisition function in our domain.

# %%
## Play here!
xi = 1
# xi = 10 # This should make it converge to the right optima
initial_x = 1
## Now stop playing.

def suggest_next_point(gp, acquisition_function, train_x, train_y, **kwargs):
    if len(train_x) == 0:
        return 1
    sigma_f = train_gp(gp, train_x, train_y)
    acq_score = acquisition_function(gp, xs, sigma_f, np.max(train_y), **kwargs)
    return xs[np.argmax(acq_score), 0]

train_x = [initial_x]
train_y = [y(initial_x)]
for i in range(4):
    next_point = suggest_next_point(gp, PI, train_x, train_y, xi=xi)
    print(f'Next point: {next_point}')
    train_x.append(next_point)
    train_y.append(y(next_point))
    
    func_plot.reset()
    sigma_f = train_gp(gp, train_x, train_y)
    f_best = np.max(train_y)
    plot_gp(func_plot, gp, sigma_f)
    plot_PI(func_plot, gp, sigma_f, f_best, xi=xi)
    display(fig)
# Out:
# Next point: 0.6060606060606061
# Next point: 0.20202020202020202
# Next point: 0.20202020202020202
# Next point: 0.20202020202020202

# %% [markdown]
# Unfortunately it still becomes stuck in a local minimum unless we pick a very large $\xi \ge 10$.
#
# ### Expected Improvement $a_\text{EI}$
#
# In expected improvement, we weight the probability of improvement by sampling at $x$ with the quantity of improvement $f(x_best) - \mu(x)$. The formula is given below, with couple alternative representations that may or may not make more sense to you.
#
# \begin{align}
# a_\text{EI}(x) &= \sigma(x; \{x_n,y_n\}, \theta)\left(\gamma(x) \Phi(\gamma(x)) + \mathcal{N}(\gamma(x); 0, 1)\right)\\\\
# &= (f(x_\text{best}) - \mu(x) - \xi)\Phi(\gamma(x)) + \sigma\mathcal{N}(\gamma(x); 0, 1))\\\\
# &= (- \Delta y)P(|\Delta y| \ge \xi) + \sigma P(\Delta y)
# \end{align}
#
# Note that since $\gamma$ is part of the equation, we can continue to use the hyperparamter $\xi$ to modify the function.
#
# My intuition for expected improvement is this: suppose that I offer you to play one of two games with you. The games available are as follows:
#  - We flip a coin, if you call it right I give you \\$1
#  - We roll a dice, if you call it right I give you \\$100
#
# You would probably elect to play the second game, even though your probability of winning the first game is much higher (1/2 vs 1/6). This is because your expected winnings from the first game are only 50 cents (1/2 * 1) compared to \\$17 for the second game (1/6 * 100). Over multiple rounds (assuming both games take the same amount of time per round) you will make much more money playing the second game. This expectation is represented by the term $(- \Delta y)P(|\Delta y| \ge \xi)$ in the equation - the amount of gain weighted by the probability of a gain.

# %%
def EI(gp, x, sigma_f, f_best, xi=0):
    mean, std = scaled_predict(gp, x, sigma_f)
    gamma = np.divide(f_best - mean.reshape(-1) - xi, std.reshape(-1))
    prob_gamma = stats.norm.pdf(gamma, 0, 1)
    return std * (gamma * stats.norm.cdf(gamma) + prob_gamma)

def plot_EI(func_plot, gp, sigma_f, f_best, xi=0, scale=5):
    func_plot.add_function(f'$a_{{EI}}$ ($\\xi={xi}$)',
                           lambda x: EI(gp, x, sigma_f, f_best, xi) * scale, 
                           style='y--', f_sigma_style='b', 
                           linewidth=2.5)

func_plot.reset()
gp, sigma_f = init_gp()


train_x, train_y = [1], [y(1)]
sigma_f = train_gp(gp, train_x, train_y)
f_best = np.max(train_y)

plot_gp(func_plot, gp, sigma_f)
plot_EI(func_plot, gp, sigma_f, f_best)
display(fig)

# %%
## Play here!
xi = 1
initial_x = 1
## Now stop playing.

train_x, train_y = [initial_x], [y(initial_x)]
for i in range(4):
    next_point = suggest_next_point(gp, EI, train_x, train_y, xi=xi)
    print(f'Next point: {next_point}')
    train_x.append(next_point)
    train_y.append(y(next_point))
    
    func_plot.reset()
    sigma_f = train_gp(gp, train_x, train_y)
    f_best = np.max(train_y)
    plot_gp(func_plot, gp, sigma_f)
    plot_EI(func_plot, gp, sigma_f, f_best, xi=xi)
    display(fig)
# Out:
# Next point: 1.5151515151515151
# Next point: 0.0
# Next point: 0.0
# Next point: 0.0

# %% [markdown]
# Unfortunately even EI often gets stuck in a local minimum unless $\xi \ge 5$.
#
# ### Upper (or Lower) Confidence Bound $a_\text{LCB}$
#
# Lastly (in this notebook), we consider the Upper/Lower Confidence Bound. There is a key distinction between this acquisition and the previous two; previously, we considered our probability of improving on our best value (by some amount $\xi$) through sampling at a new point $x$, or, the expected improvement from sampling at $x$. You should consider how these to lead to **pragmatic estimates**; you can prove that, from a probabilistic standpoint, the points suggested by the previous acqusition functions are the most likely to improve on our previous best value.
#
# However, in practice the UCB/LCB is often found to perform better as an acquisition function; it produces **optimistic estimates**. This is because UCB/LCB assumes that, for a sample location $x$, the measured value at that location will be $\kappa \ge 0$ standard deviations $\sigma$ above/below the mean $\mu$. For any $\kappa > 0$, we clearly see that this wil mostly be wrong. In fact, if we pick $\kappa = 3$, we would expect that $99.9%$ of actual samples will be worse than UCB/LCB told us. However, the important thing is not that the acquisition function has a sensible physical interpretation; instead, what matters is how useful relative values of the acqusition function are at point $x_1$ vs $x_2$.
#
# UCB/LCB is simple to calculate and optimize over $x\in\mathcal{X}$, which is one reason it is popularly used. Another reason is that $\kappa$ works directly as an exploration/exploitation trade-off. High values of $\kappa$ will lead to the acquisition prioritizing parts of the domain with high variance, while low values prioritize regions where the mean is favourable (high/low for maximizing/minimizing). It has been found in practice that finding an appropriate value of $\kappa$ is often quite easy if we know a bit about $f(x)$, but this is still an area of investigation.
#
# \begin{align}
# a_\text{UCB} &= \kappa\sigma(x; \{x_n, y_n\}, \theta) + \mu(x; \{x_n, y_n\}, \theta)\\
# a_\text{LCB} &= \kappa\sigma(x; \{x_n, y_n\}, \theta) - \mu(x; \{x_n, y_n\}, \theta)
# \end{align}

# %%
## Play here!
initial_x = 1
kappa = 1
## Now stop playing.

def UCB(gp, x, sigma_f, _, kappa=1):
    mean, std = scaled_predict(gp, x, sigma_f)
    return  kappa * std + mean

def LCB(gp, x, sigma_f, _, kappa=1):
    mean, std = scaled_predict(gp, x, sigma_f)
    return kappa * std - mean

def plot_LCB(func_plot, gp, sigma_f, f_best, kappa=0, scale=1):
    func_plot.add_function(f'$a_{{LCB}}$ ($\\kappa={kappa}$)',
                           lambda x: LCB(gp, x, sigma_f, f_best, kappa) * scale, 
                           style='y--', linewidth=2.5)

func_plot.reset()
gp, sigma_f = init_gp()


train_x, train_y = [initial_x], [y(initial_x)]
sigma_f = train_gp(gp, train_x, train_y)
f_best = np.max(train_y)

plot_gp(func_plot, gp, sigma_f)
func_plot.add_function(f'$a_{{UCB}}$ ($\\kappa={1}$)',
                       lambda x: UCB(gp, x, sigma_f, f_best, 1),
                       style='m--', linewidth=2.5)
plot_LCB(func_plot, gp, sigma_f, f_best, kappa=kappa)
display(fig)

# %%
## Play here!
initial_x = 1
kappa = 2
## Now stop playing.

train_x, train_y = [initial_x], [y(initial_x)]
for i in range(4):
    next_point = suggest_next_point(gp, LCB, train_x, train_y, kappa=kappa)
    print(f'Next point: {next_point}')
    train_x.append(next_point)
    train_y.append(y(next_point))
    
    func_plot.reset()
    sigma_f = train_gp(gp, train_x, train_y)
    f_best = np.max(train_y)
    plot_gp(func_plot, gp, sigma_f)
    plot_LCB(func_plot, gp, sigma_f, f_best, kappa=kappa)
    display(fig)
# Out:
# Next point: 1.6161616161616161
# Next point: 0.0
# Next point: 6.565656565656566
# Next point: 10.0

# %% [markdown]
# # ML Algorithm Hyperparameter Tuning Experiments
# #### Taken from: Snoek, J., Larochelle, H., & Adams, R. P. (2012). Practical Bayesian Optimization of Machine Learning Algorithms. Retrieved from http://arxiv.org/abs/1206.2944
#
# ## MNIST
#
# ![MNIST-comparison.png](MNIST-comparison.png)
#
# Notes:
#  - f(x) represents training a neural network on the MNIST dataset and returning the terminal loss
#  - BO methods outperform the Tree-Parzan algorithm
#  - Taking time to collect samples into account leads to a big improvement
#    - Likely because size of the network and number of epochs are parameters in $x$ that greatly affect the time taken to collect a particular sample
#    - Instead of `(expected improvement) / sample`, we optimize for `(expected improvement) / second` -> works better
#
# ## Online LDA
#
# ![online-lda-parallelization.png](online-lda-parallelization.png)
#
# Notes:
#  - f(x) represents training an LDA model on a text corpus
#  - Parallization makes a big improvement; see paper and sections below for more details on how to parallelize BO
#
# ## Convolutional Neural Network
#
# ![cnn-tuning.png](cnn-tuning.png)
#
# Notes:
#  - Yet another example, same comments as preiously apply

# %% [markdown]
# # Integrating Acquisition Functions
# #### Taken from: Snoek, J., Larochelle, H., & Adams, R. P. (2012). Practical Bayesian Optimization of Machine Learning Algorithms. Retrieved from http://arxiv.org/abs/1206.2944
#
# ## Integrating over GP Hyperparameters
#
# ![integrating-acquistion-function-over-model-hyperparameters.png](integrating-acquistion-function-over-model-hyperparameters.png)
#
#  - Here, different lines in the top plot represent different GPs which model the same samples (dark dots) with different GP hyperparameters (specifically, different length scales)
#  - The second plot represents the same acquisiton function (expected improvement) computed for each of the GPs in the top plot
#  - The third plot shows the sum of the three different acquisition functions; this represents a "compound" acqusition function that helps us avoid the issue of not knowing which GP hyperparameters to use (e.g. what length scale)
#
# ## Integrating over Pending Evaluations
#
# ![integrating-acquistion-function-over-pending-evaluations.png](integrating-acquistion-function-over-pending-evaluations.png)
#
#  - Here, different lines in the top plot represent different GPs which model the same samples (dark dots) with different possible evaluations $f(x_\text{new,1}), f(x_\text{new,2})$ at the points being tested by concurrent Bayesian optimization routines (the points $x_\text{new,1}$ and $x_\text{new,2}$ are the x-coordinates of the triplicate sets of coloured points)
#  - The second plot represents the same acquisiton function (expected improvement) computed for each of the GPs in the top plot
#  - The third plot shows the sum of the three different acquisition functions; this represents a "compound" acqusition function over all possible futures that could result from the sample values attained by the concurrent Bayesian optimization routines. This helps us to pick a point to sample that will be very informative regardless of the outcomes of the concurrent sampling routines.
